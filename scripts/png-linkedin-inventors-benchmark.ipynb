# %%
try:
    import pandas as pd
except:
    raise Exception("Unable to import pandas. Please install required dependencies.")

data = pd.read_csv("../data-raw/png-linkedin-patent-dataset/pat_lkn.csv")

# %%
# TODO: make this into a benchmark. Will require matching to rawinventor.
# Out:
#              lower  year    lkn_id  \
# 0       03860477-1  1963  57576672
# 1       03860477-1  1964  57576672
# 2       03860477-1  1965  57576672
# 3       03860477-1  1966  57576672
# 4       03860477-1  1967  57576672
# ...            ...   ...       ...
# 210549  PP016238-1  1999   2027808
# 210550  PP016238-1  2000   2027808
# 210551  PP016238-1  2001   2027808
# 210552  PP016238-1  2002   2027808
# 210553  PP016238-1  2003   2027808
#
#                                                       url  zipcode  patlife  \
# 0       http://www.linkedin.com/pub/craig-johnson/17/9...      NaN      NaN
# 1       http://www.linkedin.com/pub/craig-johnson/17/9...      NaN      NaN
# 2       http://www.linkedin.com/pub/craig-johnson/17/9...      NaN      NaN
# 3       http://www.linkedin.com/pub/craig-johnson/17/9...      NaN      NaN
# 4       http://www.linkedin.com/pub/craig-johnson/17/9...      NaN      NaN
# ...                                                   ...      ...      ...
# ...
